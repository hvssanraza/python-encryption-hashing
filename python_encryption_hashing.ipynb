# %% [markdown]
# <a href="https://colab.research.google.com/github/hvssanraza/python-encryption-hashing/blob/main/python_encryption_hashing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cryptography
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography) (2.23)
# Mounted at /content/drive

# %%
with open("/content/drive/My Drive/file.txt", "r") as f:
    print(f.read())
# Out:
# Hello, I am Hassan Raza and this is my first Information Security lab.

# %%
from cryptography.fernet import Fernet

key = Fernet.generate_key()
print("Generated Key:", key.decode())

cipher = Fernet(key)
input_file = "/content/drive/My Drive/file.txt"
with open(input_file, "rb") as f:
    data = f.read()

encrypted_data = cipher.encrypt(data)

encrypted_file = "/content/drive/My Drive/encrypted_file.txt"
with open(encrypted_file, "wb") as f:
    f.write(encrypted_data)

print("File encrypted successfully:", encrypted_file)

with open(encrypted_file, "rb") as f:
    encrypted_data = f.read()

decrypted_data = cipher.decrypt(encrypted_data)

decrypted_file = "/content/drive/My Drive/decrypted_file.txt"
with open(decrypted_file, "wb") as f:
    f.write(decrypted_data)

print("Decryption successful. Decrypted file saved as:", decrypted_file)
# Out:
# Generated Key: LJ2PPslxYWCekbPEy-CfYqqggbrFkBG2_Q3SrN45KKU=
# File encrypted successfully: /content/drive/My Drive/encrypted_file.txt
# Decryption successful. Decrypted file saved as: /content/drive/My Drive/decrypted_file.txt

# %%
import hashlib

input_file = "/content/drive/My Drive/file.txt"
with open(input_file, "rb") as f:
    data = f.read()

md5_hash = hashlib.md5(data).hexdigest()
sha1_hash = hashlib.sha1(data).hexdigest()
sha256_hash = hashlib.sha256(data).hexdigest()

print("Original File Hashes:")
print("MD5:   ", md5_hash)
print("SHA1:  ", sha1_hash)
print("SHA256:", sha256_hash)

with open("/content/drive/My Drive/hashes.txt", "w") as f:
    f.write("MD5:    " + md5_hash + "\n")
    f.write("SHA1:   " + sha1_hash + "\n")
    f.write("SHA256: " + sha256_hash + "\n")
# Out:
# Original File Hashes:
# MD5:    8dd986dcec9ba31cd6ffc6624f84ba43
# SHA1:   b2d7e568fa8948cd63437e846d322810e981849f
# SHA256: 7ac32839f53fe7e60cfe681deead1c0368c3aa6e755383e54de4be3e4ae64119

# %%
# Read original file
with open("/content/drive/My Drive/file.txt", "r") as f:
    original_content = f.read()

# Modify content (add a new line)
modified_content = original_content + "\nThis is a modified version."

# Save as file_modified.txt
modified_file = "/content/drive/My Drive/file_modified.txt"
with open(modified_file, "w") as f:
    f.write(modified_content)

print("Modified file created at:", modified_file)
# Out:
# Modified file created at: /content/drive/My Drive/file_modified.txt

# %%
modified_file = "/content/drive/My Drive/file_modified.txt"
with open(modified_file, "rb") as f:
    mod_data = f.read()

md5_mod = hashlib.md5(mod_data).hexdigest()
sha1_mod = hashlib.sha1(mod_data).hexdigest()
sha256_mod = hashlib.sha256(mod_data).hexdigest()

print("Modified File Hashes:")
print("MD5:   ", md5_mod)
print("SHA1:  ", sha1_mod)
print("SHA256:", sha256_mod)

print("\n--- Comparison ---")
print("MD5 same?   ", md5_hash == md5_mod)
print("SHA1 same?  ", sha1_hash == sha1_mod)
print("SHA256 same?", sha256_hash == sha256_mod)
# Out:
# Modified File Hashes:
# MD5:    d39cc9b6e527e16f00ab630d7c4eb669
# SHA1:   bfdc732a9e7239e3c8c6fba33ac4997627fb4e17
# SHA256: fea1d54009f913c90b6b75fbab8c172d7fb2d45cfbe7d1d8f8fa52e6dc3726ed
#
# --- Comparison ---
# MD5 same?    False
# SHA1 same?   False
# SHA256 same? False
